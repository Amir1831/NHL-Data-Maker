# %% [markdown]
# # Fetch data

# %%
import requests
import json 
import pandas as pd
import numpy as np
def read_key(dir):
    f = open(dir,"r")
    return f.readline()[:-1]

def fetch_Data(url , key=read_key('../.key_subscription')):
    
    headers = {"Ocp-Apim-Subscription-Key": key,
            'Content-Type': 'application/json'}
    res = requests.get(url, headers=headers)


    response = json.loads(res.text)
    return response

# %% [markdown]
# ## News_by_date

# %%
url = "https://api.sportsdata.io/v3/nhl/scores/json/NewsByDate/2023-11-01"
data_2 = fetch_Data(url)
data_2
# Out:
# [{'NewsID': 27140,
#   'PlayerID': 30003147,
#   'TeamID': 1,
#   'Team': 'BOS',
#   'Title': 'Charlie McAvoy Suspended Four Games',
#   'Content': "Boston Bruins defenseman Charlie McAvoy has received a four-game suspension for an illegal check to the head of Florida Panthers defenseman Oliver Ekman-Larsson. The incident resulted in McAvoy getting a match penalty in Monday's game, and he'll now have plenty of time to think about his actions. McAvoy scored in a second consecutive game Monday and has been on fire with eight points in nine games. The Bruins also lost Matt Grzelcyk (upper body) to injury in Monday's game, meaning the entire first defensive pairing got wiped out in one night. Hampus Lindholm and Brandon Carlo should receive a nice boost in playing time now, while the rest of the blue line will need to put in extra shifts as well. McAvoy will be eligible to return to action on Nov. 11 against Montreal.",
#   'Url': 'https://www.rotoballer.com/player-news/charlie-mcavoy-suspended-four-games/1264216',
#   'Source': 'RotoBaller',
#   'TermsOfUse': "RotoBaller Premium News feeds are provided for commercial use and in accordance to the terms set forth within your SportsDataIO's commercial agreement. Please contact sales@sportsdata.io with any questions.",
#   'Updated': '2023-11-01T14:41:02'}]

# %%
df_2 = pd.DataFrame(data_2)
df_2.columns
# Out:
# Index(['NewsID', 'PlayerID', 'TeamID', 'Team', 'Title', 'Content', 'Url',
#        'Source', 'TermsOfUse', 'Updated'],
#       dtype='object')

# %%
df_2["Updated"].value_counts(dropna=False
                             )
# Out:
# 2023-11-01T14:41:02    1
# Name: Updated, dtype: int64

# %% [markdown]
# ## Make_dataset

# %%
from datetime import datetime , timedelta
now = datetime.now() 
now.strftime("%Y/%m/%d") , now
# Out:
# ('2023/11/16', datetime.datetime(2023, 11, 16, 1, 49, 43, 72363))

# %%
df_Game = []
df_news = []
days = 30
for i in range(1,days):
    date_Game = (now - timedelta(days=i)).strftime("%Y-%m-%d")
    date_News = (now - timedelta(days=i+1)).strftime("%Y-%m-%d")
    url = f"https://api.sportsdata.io/v3/nhl/scores/json/GamesByDate/{date_Game}"
    data_Game = fetch_Data(url)
    url = f"https://api.sportsdata.io/v3/nhl/scores/json/NewsByDate/{date_News}"
    data_News = fetch_Data(url)
    # if len(data_Game) and len(data_News): # if there is no game , we dont want news and if there is no news we dont want game stat !
    df_Game.append(pd.DataFrame(data_Game)[["GameID","DateTime","IsClosed","AwayTeamID","HomeTeamID","AwayTeamScore","HomeTeamScore"]])
    for dic in data_News : # add the date to the data
        dic["DateTime"] = datetime.strptime(date_News, '%Y-%m-%d')
    df_news.append(pd.DataFrame(data_News)[["TeamID" , "NewsID" , "Content" , "DateTime" ,"Url","Source"]])

df_Game = pd.concat(df_Game,ignore_index=True)
df_news = pd.concat(df_news,ignore_index=True)


df_Game["DateTime"] = df_Game["DateTime"].apply(lambda x : datetime.strptime(x.split("T")[0], '%Y-%m-%d'))

# %%
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TeamID    28 non-null     object
#  1   NewsID    29 non-null     int64
#  2   Content   29 non-null     object
#  3   DateTime  29 non-null     datetime64[ns]
#  4   Url       29 non-null     object
#  5   Source    29 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 1.5+ KB

# %%
df_Game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   GameID         193 non-null    int64
#  1   DateTime       193 non-null    datetime64[ns]
#  2   IsClosed       193 non-null    bool
#  3   AwayTeamID     193 non-null    int64
#  4   HomeTeamID     193 non-null    int64
#  5   AwayTeamScore  189 non-null    object
#  6   HomeTeamScore  189 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(3), object(2)
# memory usage: 9.4+ KB

# %% [markdown]
# map away team `game` to away team `news` and home team `game` to home team `news`

# %%
Away_df = pd.merge(df_Game , df_news ,how="inner" , left_on="AwayTeamID" , right_on="TeamID")
Home_df = pd.merge(df_Game , df_news ,how="inner" , left_on="HomeTeamID" , right_on="TeamID")

# %% [markdown]
# Determine an `Interval`

# %%
pivot_0 = pd.Timedelta(days=0)
pivot_1 = pd.Timedelta(days=7)

# %%
mask_Away = (pivot_0 < (Away_df["DateTime_x"] - Away_df["DateTime_y"])) & ((Away_df["DateTime_x"] - Away_df["DateTime_y"]) < pivot_1)
mask_home = (pivot_0 < (Home_df["DateTime_x"] - Home_df["DateTime_y"])) & ((Home_df["DateTime_x"] - Home_df["DateTime_y"]) < pivot_1)

# %% [markdown]
# Make DataFrame

# %%
final_Away_df = Away_df[mask_Away].sort_values(by="DateTime_x",ascending=False).reset_index()

# %%
final_Home_df = Home_df[mask_home].sort_values(by="DateTime_x",ascending=False).reset_index()

# %% [markdown]
# Map *News* to `Nearest` *game*

# %%
final_Away_df["DiffrenceInDay"] = final_Away_df["DateTime_x"] - final_Away_df["DateTime_y"]
final_Home_df["DiffrenceInDay"] = final_Home_df["DateTime_x"] - final_Home_df["DateTime_y"]
dup_Away = final_Away_df.sort_values(by="DiffrenceInDay")["NewsID"].duplicated(keep="first")
dup_Home = final_Home_df.sort_values(by="DiffrenceInDay")["NewsID"].duplicated(keep="first")
final_Away_df = final_Away_df[dup_Away.apply(lambda x : not x)]
final_Home_df = final_Home_df[dup_Home.apply(lambda x : not x)]
# Out:
# /tmp/ipykernel_13494/2858751293.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   final_Away_df = final_Away_df[dup_Away.apply(lambda x : not x)]
# /tmp/ipykernel_13494/2858751293.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   final_Home_df = final_Home_df[dup_Home.apply(lambda x : not x)]

# %%
final_Away_df
# Out:
#     index  GameID DateTime_x  IsClosed AwayTeamID  HomeTeamID AwayTeamScore  \
# 0      72   20858 2023-11-14      True          8          27             1
# 2      53   20855 2023-11-14      True          6          20             0
# 4      48   20839 2023-11-11      True         29          21            11
# 5      23   20827 2023-11-10      True         24           7             1
# 9      62   20795 2023-11-05      True         10          17             6
# 10     29   20794 2023-11-04      True         24          36             1
# 12     28   20794 2023-11-04      True         24          36             1
# 13    144   20790 2023-11-04      True         12          23             1
# 14     10   20782 2023-11-04      True          1           3             1
# 15      4   20778 2023-11-03      True         13           2             8
# 18  https://www.rotoballer.com/player-news/eric-co...  RotoBaller
# 19  https://www.rotoballer.com/player-news/andrei-...  RotoBaller
# 20  https://www.rotoballer.com/player-news/tanner-...  RotoBaller
# 21  https://www.rotoballer.com/player-news/tage-th...  RotoBaller
# 23  https://www.rotoballer.com/player-news/ilya-mi...  RotoBaller
# 25  https://www.rotoballer.com/player-news/connor-...  RotoBaller
# 26  https://www.rotoballer.com/player-news/kirby-d...  RotoBaller
# 27  https://www.rotoballer.com/player-news/kevin-l...  RotoBaller
# 28  https://www.rotoballer.com/player-news/timo-me...  RotoBaller
#
#    DiffrenceInDay
# 0          1 days
# 2          6 days
# 4          1 days
# 5          4 days
# 9          1 days
# 10         6 days
# 12         5 days
# 13         1 days
# 14         3 days
# 15         1 days
# 16         2 days
# 18         4 days
# 19         3 days
# 20         6 days
# 21         2 days
# 23         3 days
# 25         1 days
# 26         5 days
# 27         1 days
# 28         3 days

# %%
final_Home_df
# Out:
#     index  GameID DateTime_x  IsClosed  AwayTeamID HomeTeamID AwayTeamScore  \
# 0       4   20860 2023-11-15     False          36         25          None
# 4     124   20826 2023-11-10      True          15         10             1
# 7      94   20818 2023-11-09      True          17          6             6
# 10    110   20811 2023-11-08      True           5          7             1
# 11     83   20804 2023-11-07      True           3         12             4
# 12    137   20806 2023-11-07      True          21         24             3
# 13    115   20797 2023-11-06      True           6          7             1
# 14     72   20798 2023-11-06      True          16          8             1
# 15    159   20784 2023-11-04      True          26         13             1
# 17    133   20766 2023-11-02      True           7          1             1
# 18    143   20763 2023-11-01      True          18         24             7
# 19    142   20763 2023-11-01      True          18         24             7
# 20     30   20747 2023-10-29      True          19          2             0
# 22     31   20747 2023-10-29      True          19          2             0
# 25     59   20735 2023-10-27      True          23         15             1
# 26     23   20736 2023-10-27      True          20         28             0
# 28     48   20724 2023-10-26      True          16          4             6
# 29     15   20731 2023-10-26      True          12         25             6
# 30    152   20717 2023-10-24      True          12         24             7
# 33     53   20689 2023-10-21      True          15          4             2
# 34     91   20686 2023-10-21      True           3          5             4
#
#    HomeTeamScore TeamID  NewsID  \
# 0           None     25   27356
# 4              0     10   27196
# 7              4      6   27255
# 10             0      7   27239
# 11             7     12   27173
# 12             5     24   27224
# 13             1      7   27211
# 14             1      8   27126
# 15             0     13   27159
# 17             1      1   27140
# 18             6     24   27102
# 19             6     24   27108
# 20             2      2   27088
# 22             2      2   27048
# 25             2     15   27062
# 26             3     28   26982
# 28             8      4   27033
# 29             0     25   27015
# 30             2     24   27002
# 33             3      4   26927
# 34             2      5   26942
#
#                                               Content DateTime_y  \
# 0   Edmonton Oilers center/left wing Leon Draisait... 2023-11-14
# 4   New Jersey Devils forward Jack Hughes sustaine... 2023-11-04
# 7   Tampa Bay Lightning goaltender Matt Tomkins co... 2023-11-08
# 10  Toronto Maple Leafs center Auston Matthews con... 2023-11-07
# 11  New York Rangers defenseman Adam Fox left Thur... 2023-11-03
# 12  Calgary Flames winger Andrew Mangiapane has be... 2023-11-06
# 13  Toronto Maple Leafs center Auston Matthews pot... 2023-11-05
# 14  Florida Panthers center Sam Bennett was limite... 2023-10-31
# 15  Philadelphia Flyers goaltender Carter Hart had... 2023-11-02
# 17  Boston Bruins defenseman Charlie McAvoy has re... 2023-11-01
# 18  Calgary Flames center Adam Ruzicka (shoulder) ... 2023-10-29
# 19  Calgary Flames defenseman MacKenzie Weegar tal... 2023-10-30
# 20  Buffalo Sabres goaltender Eric Comrie sustaine... 2023-10-28
# 22  Buffalo Sabres forward Tage Thompson came to l... 2023-10-25
# 25  Washington Capitals defenseman Rasmus Sandin l... 2023-10-26
# 26  Vancouver Canucks forward Ilya Mikheyev (knee)... 2023-10-21
# 28  Montreal Canadiens left wing Tanner Pearson co... 2023-10-24
# 29  Edmonton Oilers center Connor McDavid (upper b... 2023-10-23
# 30  The Calgary Flames are planning to appeal Rasm... 2023-10-22
# 33  Montreal Canadiens center Kirby Dach has been ... 2023-10-18
# 34  Ottawa Senators defenseman Artem Zub was force... 2023-10-19
#
#                                                   Url      Source  \
# 0   https://www.rotoballer.com/player-news/leon-dr...  RotoBaller
# 4   https://www.rotoballer.com/player-news/jack-hu...  RotoBaller
# 7   https://www.rotoballer.com/player-news/matt-to...  RotoBaller
# 10  https://www.rotoballer.com/player-news/auston-...  RotoBaller
# 11  https://www.rotoballer.com/player-news/adam-fo...  RotoBaller
# 12  https://www.rotoballer.com/player-news/andrew-...  RotoBaller
# 13  https://www.rotoballer.com/player-news/auston-...  RotoBaller
# 14  https://www.rotoballer.com/player-news/sam-ben...  RotoBaller
# 15  https://www.rotoballer.com/player-news/carter-...  RotoBaller
# 17  https://www.rotoballer.com/player-news/charlie...  RotoBaller
# 18  https://www.rotoballer.com/player-news/adam-ru...  RotoBaller
# 19  https://www.rotoballer.com/player-news/mackenz...  RotoBaller
# 20  https://www.rotoballer.com/player-news/eric-co...  RotoBaller
# 22  https://www.rotoballer.com/player-news/tage-th...  RotoBaller
# 25  https://www.rotoballer.com/player-news/rasmus-...  RotoBaller
# 26  https://www.rotoballer.com/player-news/ilya-mi...  RotoBaller
# 28  https://www.rotoballer.com/player-news/tanner-...  RotoBaller
# 29  https://www.rotoballer.com/player-news/connor-...  RotoBaller
# 30  https://www.rotoballer.com/player-news/flames-...  RotoBaller
# 33  https://www.rotoballer.com/player-news/kirby-d...  RotoBaller
# 34  https://www.rotoballer.com/player-news/artem-z...  RotoBaller
#
#    DiffrenceInDay
# 0          1 days
# 4          6 days
# 7          1 days
# 10         1 days
# 11         4 days
# 12         1 days
# 13         1 days
# 14         6 days
# 15         2 days
# 17         1 days
# 18         3 days
# 19         2 days
# 20         1 days
# 22         4 days
# 25         1 days
# 26         6 days
# 28         2 days
# 29         3 days
# 30         2 days
# 33         3 days
# 34         2 days

# %% [markdown]
# ## Save data

# %%
final_Away_df.to_csv("./Away_data.csv",index=False)
final_Home_df.to_csv("./Home_data.csv",index=False)

# %%
final_Away_df["NewsID"].duplicated()
# Out:
# 0     False
# 2     False
# 4     False
# 5     False
# 9     False
# 10    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 18    False
# 19    False
# 20    False
# 21    False
# 23    False
# 25    False
# 26    False
# 27    False
# 28    False
# Name: NewsID, dtype: bool
