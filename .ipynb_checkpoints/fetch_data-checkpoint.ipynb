# %% [markdown]
# # Fetch data

# %%
import requests
import json 
import pandas as pd
import numpy as np 
def fetch_Data(url , key="19cd79a263c04613b91a4f4ce5ed8bda"):
    
    headers = {"Ocp-Apim-Subscription-Key": key,
            'Content-Type': 'application/json'}
    res = requests.get(url, headers=headers)


    response = json.loads(res.text)
    return response

# %% [markdown]
# ## News_by_date

# %%
url = "https://api.sportsdata.io/v3/nhl/scores/json/NewsByDate/2023-11-01"
data_2 = fetch_Data(url)
data_2
# Out:
# [{'NewsID': 27140,
#   'PlayerID': 30003147,
#   'TeamID': 1,
#   'Team': 'BOS',
#   'Title': 'Charlie McAvoy Suspended Four Games',
#   'Content': "Boston Bruins defenseman Charlie McAvoy has received a four-game suspension for an illegal check to the head of Florida Panthers defenseman Oliver Ekman-Larsson. The incident resulted in McAvoy getting a match penalty in Monday's game, and he'll now have plenty of time to think about his actions. McAvoy scored in a second consecutive game Monday and has been on fire with eight points in nine games. The Bruins also lost Matt Grzelcyk (upper body) to injury in Monday's game, meaning the entire first defensive pairing got wiped out in one night. Hampus Lindholm and Brandon Carlo should receive a nice boost in playing time now, while the rest of the blue line will need to put in extra shifts as well. McAvoy will be eligible to return to action on Nov. 11 against Montreal.",
#   'Url': 'https://www.rotoballer.com/player-news/charlie-mcavoy-suspended-four-games/1264216',
#   'Source': 'RotoBaller',
#   'TermsOfUse': "RotoBaller Premium News feeds are provided for commercial use and in accordance to the terms set forth within your SportsDataIO's commercial agreement. Please contact sales@sportsdata.io with any questions.",
#   'Updated': '2023-11-01T14:41:02'}]

# %%
df_2 = pd.DataFrame(data_2)
df_2.columns
# Out:
# Index(['NewsID', 'PlayerID', 'TeamID', 'Team', 'Title', 'Content', 'Url',
#        'Source', 'TermsOfUse', 'Updated'],
#       dtype='object')

# %%
df_2["Updated"].value_counts(dropna=False
                             )
# Out:
# 2023-11-01T14:41:02    1
# Name: Updated, dtype: int64

# %% [markdown]
# ## Make_dataset

# %%
from datetime import datetime , timedelta
now = datetime.now() 
now.strftime("%Y/%m/%d") , now
# Out:
# ('2023/11/09', datetime.datetime(2023, 11, 9, 1, 17, 27, 895142))

# %%
len({"a":1 , "b":2})
# Out:
# 2

# %%
df_Game = []
df_news = []
days = 120
for i in range(1,50):
    date_Game = (now - timedelta(days=i)).strftime("%Y-%m-%d")
    date_News = (now - timedelta(days=i+1)).strftime("%Y-%m-%d")
    url = f"https://api.sportsdata.io/v3/nhl/scores/json/GamesByDate/{date_Game}"
    data_Game = fetch_Data(url)
    url = f"https://api.sportsdata.io/v3/nhl/scores/json/NewsByDate/{date_News}"
    data_News = fetch_Data(url)
    if len(data_Game) and len(data_News): # if there is no game , we dont want news and if there is no news we dont want game stat !
        df_Game.append(pd.DataFrame(data_Game)[["GameID","DateTime","IsClosed","AwayTeamID","HomeTeamID","AwayTeamScore","HomeTeamScore"]])
        for dic in data_News : # add the date to the data
            dic["DateTime"] = datetime.strptime(date_News, '%Y-%m-%d')
        df_news.append(pd.DataFrame(data_News)[["TeamID" , "Content" , "DateTime"]])

df_Game = pd.concat(df_Game,ignore_index=True)
df_news = pd.concat(df_news,ignore_index=True)


df_Game["DateTime"] = df_Game["DateTime"].apply(lambda x : datetime.strptime(x.split("T")[0], '%Y-%m-%d'))

# %%
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TeamID    42 non-null     object
#  1   Content   43 non-null     object
#  2   DateTime  43 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 1.1+ KB

# %%
df_Game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   GameID         291 non-null    int64
#  1   DateTime       291 non-null    datetime64[ns]
#  2   IsClosed       291 non-null    bool
#  3   AwayTeamID     291 non-null    int64
#  4   HomeTeamID     291 non-null    int64
#  5   AwayTeamScore  288 non-null    object
#  6   HomeTeamScore  288 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(3), object(2)
# memory usage: 14.0+ KB

# %% [markdown]
# map away team `game` to away team `news` and home team `game` to home team `news`

# %%
Away_df = pd.merge(df_Game , df_news ,how="inner" , left_on="AwayTeamID" , right_on="TeamID")
Home_df = pd.merge(df_Game , df_news ,how="inner" , left_on="HomeTeamID" , right_on="TeamID")

# %%
zero_days = pd.Timedelta(days=0)
seven_days = pd.Timedelta(days=7)

mask_Away = (zero_days < (Away_df["DateTime_x"] - Away_df["DateTime_y"])) & ((Away_df["DateTime_x"] - Away_df["DateTime_y"]) < seven_days)
mask_home = (zero_days < (Home_df["DateTime_x"] - Home_df["DateTime_y"])) & ((Home_df["DateTime_x"] - Home_df["DateTime_y"]) < seven_days)

# %%
final_Away_df = Away_df[mask_Away].sort_values(by="DateTime_x",ascending=False).reset_index()
final_Away_df
# Out:
#     index  GameID DateTime_x  IsClosed AwayTeamID  HomeTeamID AwayTeamScore  \
# 0      85   20808 2023-11-07      True         10          19             4
# 1     111   20810 2023-11-07      True         13          27             1
# 2     127   20799 2023-11-06      True          1          18             0
# 3      87   20795 2023-11-05      True         10          17             6
# 4     184   20790 2023-11-04      True         12          23             1
# 5     208   20794 2023-11-04      True         24          36             1
# 6     207   20794 2023-11-04      True         24          36             1
# 7      15   20789 2023-11-04      True          8          17             0
# 8     128   20782 2023-11-04      True          1           3             1
# 9     112   20778 2023-11-03      True         13           2             8
# 10    173   20768 2023-11-02      True          9          12             0
# 11     16   20767 2023-11-02      True          8           3             1
# 12     33   20762 2023-11-01      True          2          13             9
# 13    162   20759 2023-10-30      True          4          35             0
# 14    174   20752 2023-10-30      True          9          13             0
# 15     38   20734 2023-10-27      True          2          10             2
# 16    355   20727 2023-10-26      True         27           6             0
# 17    293   20716 2023-10-24      True         28          21             7
# 18    357   20710 2023-10-24      True         27           8             2
# 19    137   20715 2023-10-24      True         25          23             9
# 20    165   20703 2023-10-23      True          4           2             2
# 21    359   20695 2023-10-21      True         27          21             1
# 22    270   20690 2023-10-21      True          7           6             3
# 23     96   20685 2023-10-20      True         10          11            14
# 24    273   20676 2023-10-19      True          7           8             1
# 25    106   20671 2023-10-18      True         14           3             0
# 26     73   20661 2023-10-17      True          6           2             3
# 27    330   20658 2023-10-16      True         17           7             1
# 28    331   20658 2023-10-16      True         17           7             1
# 29     47   20648 2023-10-14      True          2          11             0
# 30    334   20644 2023-10-14      True         17           4             0
# 31    333   20644 2023-10-14      True         17           4             0
# 32    152   20637 2023-10-12      True         35          27             1
# 33      7   20625 2023-10-11      True          5           9             5
# 34    317   22038 2023-10-07      True         30          29             3
# 35    344   22044 2023-10-07      True         17          20             9
# 36     80   22039 2023-10-07      True          6           8            12
# 37    203   22030 2023-10-05      True         19          35             8
# 38     52   22017 2023-10-04      True          2          16             3
# 39    318   22013 2023-10-03      True         30          26             3
# 40    376   22009 2023-10-03      True         15           1            13
# 41    378   21991 2023-09-30      True         15           3             3
# 42    308   21988 2023-09-29      True         29          35             0
# 43    255   21970 2023-09-27      True         24          22             0
# 44    291   21961 2023-09-26      True         11          12             2
# 45    310   21944 2023-09-24      True         29          18             0
# 46    309   21934 2023-09-24      True         29          26             3
#
#    HomeTeamScore TeamID                                            Content  \
# 0              8     10  New Jersey Devils forward Jack Hughes sustaine...
# 1              3     13  Philadelphia Flyers goaltender Carter Hart had...
# 2              0      1  Boston Bruins defenseman Charlie McAvoy has re...
# 3              3     10  New Jersey Devils forward Jack Hughes sustaine...
# 4              1     12  New York Rangers defenseman Adam Fox left Thur...
# 5              1     24  Calgary Flames center Adam Ruzicka (shoulder) ...
# 6              1     24  Calgary Flames defenseman MacKenzie Weegar tal...
# 7              1      8  Florida Panthers center Sam Bennett was limite...
# 8              1      1  Boston Bruins defenseman Charlie McAvoy has re...
# 9              2     13  Philadelphia Flyers goaltender Carter Hart had...
# 10             1      9  Carolina Hurricanes forward Andrei Svechnikov ...
# 11             0      8  Florida Panthers center Sam Bennett was limite...
# 12             4      2  Buffalo Sabres goaltender Eric Comrie sustaine...
# 13             0      4  Montreal Canadiens left wing Tanner Pearson co...
# 14             0      9  Carolina Hurricanes forward Andrei Svechnikov ...
# 15             3      2  Buffalo Sabres forward Tage Thompson came to l...
# 16            13     27  San Jose Sharks forward Kevin Labanc will suit...
# 17             5     28  Vancouver Canucks forward Ilya Mikheyev (knee)...
# 18             7     27  San Jose Sharks forward Kevin Labanc will suit...
# 19            11     25  Edmonton Oilers center Connor McDavid (upper b...
# 20             1      4  Montreal Canadiens center Kirby Dach has been ...
# 21             4     27  San Jose Sharks forward Kevin Labanc will suit...
# 22             3      7  Toronto Maple Leafs center Auston Matthews has...
# 23            11     10  New Jersey Devils winger Timo Meier was among ...
# 24             3      7  Toronto Maple Leafs center Auston Matthews has...
# 25             1     14  Pittsburgh Penguins center Sidney Crosby had t...
# 26             4      6  Tampa Bay Lightning center Steven Stamkos (low...
# 27             0     17  Chicago Blackhawks left wing Taylor Hall (uppe...
# 28             0     17  Chicago Blackhawks center Connor Bedard record...
# 29             1      2  Buffalo Sabres defenseman Rasmus Dahlin has si...
# 30             1     17  Chicago Blackhawks center Connor Bedard record...
# 31             1     17  Chicago Blackhawks left wing Taylor Hall (uppe...
# 32             0     35  Vegas Golden Knights defenseman Alec Martinez ...
# 33             9      5  Ottawa Senators forward Josh Norris (shoulder)...
# 34            12     30  Anaheim Ducks goaltender John Gibson (upper bo...
# 35            15     17  Chicago Blackhawks prospect Samuel Savoie has ...
# 36             6      6  Tampa Bay Lightning goaltender Jonas Johansson...
# 37            11     19  Colorado Avalanche goaltender Pavel Francouz (...
# 38             4      2  Buffalo Sabres center Matthew Savoie (shoulder...
# 39            10     30  Anaheim Ducks goaltender John Gibson (upper bo...
# 40            10     15  Washington Capitals defenseman Joel Edmundson ...
# 41             7     15  Washington Capitals defenseman Joel Edmundson ...
# 42             0     29  Arizona Coyotes center Logan Cooley grabbed th...
# 43             0     24  Calgary Flames left wing Jakob Pelletier was f...
# 44             5     11  New York Islanders right wing Kyle Palmieri (u...
# 45            10     29  Arizona Coyotes center Logan Cooley grabbed th...
# 46             4     29  Arizona Coyotes center Logan Cooley grabbed th...
#
#    DateTime_y
# 0  2023-11-04
# 1  2023-11-02
# 2  2023-11-01
# 3  2023-11-04
# 4  2023-11-03
# 5  2023-10-29
# 6  2023-10-30
# 7  2023-10-31
# 8  2023-11-01
# 9  2023-11-02
# 10 2023-10-27
# 11 2023-10-31
# 12 2023-10-28
# 13 2023-10-24
# 14 2023-10-27
# 15 2023-10-25
# 16 2023-10-20
# 17 2023-10-21
# 18 2023-10-20
# 19 2023-10-23
# 20 2023-10-18
# 21 2023-10-20
# 22 2023-10-15
# 23 2023-10-17
# 24 2023-10-15
# 25 2023-10-14
# 26 2023-10-16
# 27 2023-10-12
# 28 2023-10-11
# 29 2023-10-09
# 30 2023-10-11
# 31 2023-10-12
# 32 2023-10-10
# 33 2023-10-06
# 34 2023-10-01
# 35 2023-10-02
# 36 2023-10-04
# 37 2023-10-03
# 38 2023-09-29
# 39 2023-10-01
# 40 2023-09-27
# 41 2023-09-27
# 42 2023-09-23
# 43 2023-09-26
# 44 2023-09-25
# 45 2023-09-23
# 46 2023-09-23

# %%
final_Home_df = Home_df[mask_home].sort_values(by="DateTime_x",ascending=False).reset_index()
final_Home_df
# Out:
#     index  GameID DateTime_x  IsClosed  AwayTeamID HomeTeamID AwayTeamScore  \
# 0       0   20811 2023-11-08     False           5          7          None
# 1       1   20811 2023-11-08     False           5          7          None
# 2     124   20806 2023-11-07      True          21         24             3
# 3     117   20804 2023-11-07      True           3         12             4
# 4     208   20798 2023-11-06      True          16          8             1
# 5       4   20797 2023-11-06      True           6          7             1
# 6     277   20784 2023-11-04      True          26         13             1
# 7     287   20778 2023-11-03      True          13          2             8
# 8     327   20766 2023-11-02      True           7          1             1
# 9     130   20763 2023-11-01      True          18         24             7
# 10    131   20763 2023-11-01      True          18         24             7
# 11    247   20750 2023-10-29      True          24         25             1
# 12    291   20747 2023-10-29      True          19          2             0
# 13    292   20747 2023-10-29      True          19          2             0
# 14     36   20749 2023-10-29      True          27         15             0
# 15     87   20741 2023-10-28      True          22          4             6
# 16     38   20735 2023-10-27      True          23         15             1
# 17    219   20736 2023-10-27      True          20         28             0
# 18    137   20730 2023-10-26      True          20         24             6
# 19     89   20724 2023-10-26      True          16          4             6
# 20    248   20731 2023-10-26      True          12         25             6
# 21     92   20708 2023-10-24      True          10          4            11
# 22    142   20717 2023-10-24      True          12         24             7
# 23    259   20706 2023-10-24      True           2          5            14
# 24     94   20689 2023-10-21      True          15          4             2
# 25    261   20686 2023-10-21      True           3          5             4
# 26    362   20690 2023-10-21      True           7          6             3
# 27    364   20675 2023-10-19      True          28          6             3
# 28    340   20660 2023-10-16      True           3         16             1
# 29     14   20658 2023-10-16      True          17          7             1
# 30     66   20652 2023-10-14      True          30         35             0
# 31    341   20647 2023-10-14      True          12         16             1
# 32    313   20631 2023-10-12      True          12          2             1
# 33    367   20622 2023-10-10      True          21          6             1
# 34    270   22042 2023-10-07      True           4          5            10
# 35    369   22022 2023-10-05      True           8          6            16
# 36    238   22027 2023-10-05      True          23         17             8
# 37    184   22029 2023-10-05      True          29         30            11
# 38    241   22012 2023-10-03      True           3         17             5
# 39     73   22014 2023-10-03      True          27         35             5
# 40    153   22007 2023-10-02      True          22         24             3
# 41    322   21989 2023-09-30      True          16          2             4
# 42    114   22229 2023-09-30      True          12         11             4
# 43    115   21983 2023-09-29     False          12         11             0
# 44     75   21988 2023-09-29      True          29         35             0
# 45    158   21986 2023-09-29      True          25         24             0
# 46     49   21976 2023-09-28      True           3         15             3
# 47    116   21968 2023-09-27      True          13         11             0
#
#    HomeTeamScore TeamID                                            Content  \
# 0           None      7  Toronto Maple Leafs center Auston Matthews con...
# 1           None      7  Toronto Maple Leafs center Auston Matthews pot...
# 2              5     24  Calgary Flames winger Andrew Mangiapane has be...
# 3              7     12  New York Rangers defenseman Adam Fox left Thur...
# 4              1      8  Florida Panthers center Sam Bennett was limite...
# 5              1      7  Toronto Maple Leafs center Auston Matthews pot...
# 6              0     13  Philadelphia Flyers goaltender Carter Hart had...
# 7              2      2  Buffalo Sabres goaltender Eric Comrie sustaine...
# 8              1      1  Boston Bruins defenseman Charlie McAvoy has re...
# 9              6     24  Calgary Flames defenseman MacKenzie Weegar tal...
# 10             6     24  Calgary Flames center Adam Ruzicka (shoulder) ...
# 11             2     25  Edmonton Oilers center Connor McDavid (upper b...
# 12             2      2  Buffalo Sabres goaltender Eric Comrie sustaine...
# 13             2      2  Buffalo Sabres forward Tage Thompson came to l...
# 14             1     15  Washington Capitals defenseman Rasmus Sandin l...
# 15             8      4  Montreal Canadiens left wing Tanner Pearson co...
# 16             2     15  Washington Capitals defenseman Rasmus Sandin l...
# 17             3     28  Vancouver Canucks forward Ilya Mikheyev (knee)...
# 18             0     24  The Calgary Flames are planning to appeal Rasm...
# 19             8      4  Montreal Canadiens left wing Tanner Pearson co...
# 20             0     25  Edmonton Oilers center Connor McDavid (upper b...
# 21             5      4  Montreal Canadiens center Kirby Dach has been ...
# 22             2     24  The Calgary Flames are planning to appeal Rasm...
# 23             9      5  Ottawa Senators defenseman Artem Zub was force...
# 24             3      4  Montreal Canadiens center Kirby Dach has been ...
# 25             2      5  Ottawa Senators defenseman Artem Zub was force...
# 26             3      6  Tampa Bay Lightning center Steven Stamkos (low...
# 27             5      6  Tampa Bay Lightning center Steven Stamkos (low...
# 28             0     16  Columbus Blue Jackets defenseman Zach Werenski...
# 29             0      7  Toronto Maple Leafs center Auston Matthews has...
# 30             1     35  Vegas Golden Knights defenseman Alec Martinez ...
# 31             1     16  Columbus Blue Jackets defenseman Zach Werenski...
# 32             0      2  Buffalo Sabres defenseman Rasmus Dahlin has si...
# 33             2      6  Tampa Bay Lightning goaltender Jonas Johansson...
# 34            12      5  Ottawa Senators forward Josh Norris (shoulder)...
# 35             8      6  Tampa Bay Lightning goaltender Jonas Johansson...
# 36             5     17  Chicago Blackhawks prospect Samuel Savoie has ...
# 37             5     30  Anaheim Ducks goaltender John Gibson (upper bo...
# 38            10     17  Chicago Blackhawks prospect Samuel Savoie has ...
# 39             0     35  Vegas Golden Knights defenseman Zach Whiteclou...
# 40             4     24  Calgary Flames left wing Jakob Pelletier was f...
# 41             6      2  Buffalo Sabres center Matthew Savoie (shoulder...
# 42             7     11  New York Islanders right wing Kyle Palmieri (u...
# 43             0     11  New York Islanders right wing Kyle Palmieri (u...
# 44             0     35  Vegas Golden Knights defenseman Zach Whiteclou...
# 45             0     24  Calgary Flames left wing Jakob Pelletier was f...
# 46             4     15  Washington Capitals defenseman Joel Edmundson ...
# 47             0     11  New York Islanders right wing Kyle Palmieri (u...
#
#    DateTime_y
# 0  2023-11-07
# 1  2023-11-05
# 2  2023-11-06
# 3  2023-11-03
# 4  2023-10-31
# 5  2023-11-05
# 6  2023-11-02
# 7  2023-10-28
# 8  2023-11-01
# 9  2023-10-30
# 10 2023-10-29
# 11 2023-10-23
# 12 2023-10-28
# 13 2023-10-25
# 14 2023-10-26
# 15 2023-10-24
# 16 2023-10-26
# 17 2023-10-21
# 18 2023-10-22
# 19 2023-10-24
# 20 2023-10-23
# 21 2023-10-18
# 22 2023-10-22
# 23 2023-10-19
# 24 2023-10-18
# 25 2023-10-19
# 26 2023-10-16
# 27 2023-10-16
# 28 2023-10-13
# 29 2023-10-15
# 30 2023-10-10
# 31 2023-10-13
# 32 2023-10-09
# 33 2023-10-04
# 34 2023-10-06
# 35 2023-10-04
# 36 2023-10-02
# 37 2023-10-01
# 38 2023-10-02
# 39 2023-09-28
# 40 2023-09-26
# 41 2023-09-29
# 42 2023-09-25
# 43 2023-09-25
# 44 2023-09-28
# 45 2023-09-26
# 46 2023-09-27
# 47 2023-09-25

# %% [markdown]
# ## Save data

# %%
final_Away_df.to_csv("./Away_data.csv")
final_Home_df.to_csv("./Home_data.csv")
